# %%
a = [10,30,20,50,40]
print (a)
# Out:
# [10, 30, 20, 50, 40]

# %%
a.append (100)
print (a)
# Out:
# [10, 30, 20, 50, 40, 100, 100]

# %%
a.count(100)
print(a.count(100))
# Out:
# 2

# %%
c=a.copy()
c
# Out:
# [10, 30, 20, 50, 40, 100, 100]

# %%
b=[1,2,3,4,5,6]
b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
b.insert(0,0)
b
# Out:
# [0, 1, 2, 3, 4, 5, 5, 5, 6, 5]

# %%
b.remove(5)
b
# Out:
# [0, 1, 2, 3, 4, 5, 5, 6, 5]

# %%
b.sort()
b
# Out:
# [0, 1, 2, 3, 4, 5, 5, 5, 6]

# %%
b.reverse()
b
# Out:
# [6, 5, 5, 5, 4, 3, 2, 1, 0]

# %%
b.append(7)
b
# Out:
# [6, 5, 5, 5, 4, 2, 1, 0, 7, 7]

# %%
b.pop(8)
b
# Out:
# [6, 5, 5, 5, 4, 2, 1, 0, 7]

# %%
b.reverse()
b
# Out:
# [7, 0, 1, 2, 4, 5, 5, 5, 6]

# %%
b.sort()
b
# Out:
# [0, 1, 2, 4, 5, 5, 5, 6, 7]

# %%
b.extend([8,9])
b
# Out:
# [0, 1, 2, 4, 5, 5, 5, 6, 7, 8, 9]

# %%
d=[10,20,30,40,50,60,70]
d
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
d[:]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
d[3:]
# Out:
# [40, 50, 60, 70]

# %%
d[3:4]
# Out:
# [40]

# %%
x=(11,11,22,33,44,55,66,77,88,99)
x
# Out:
# (11, 11, 22, 33, 44, 55, 66, 77, 88, 99)

# %%
x.count(11)
# Out:
# 2

# %%
max(x)
# Out:
# 99

# %%
min(x)
# Out:
# 11

# %%
len(x)
# Out:
# 10

# %%
x.index(55)
# Out:
# 5
