# %%
file1 = open("C:\\Users\\RVUW262\\Desktop\\LOL\\helllo.txt", "x")

# %%
file1.write("I'm am the one and only. KING. or a God")
# Out:
# 39

# %%
file1.close()

# %%
file2 = open("C:\\Users\\RVUW262\\Desktop\\LOL\\song.txt", "x")

# %%
file2.write("Tel Aviv backed Washington DC vs Tehran")
# Out:
# 39

# %%
file2.close()

# %%
print(file2)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\RVUW262\\Desktop\\LOL\\song.txt' mode='x' encoding='cp1252'>

# %%
file=open("tron.txt","x")
file.write("Nethanyahu")
file.close()

# %%
file=open("tron.txt","w")
file.write("Tel Aviv")
file.close()

# %%
file=open("tron.txt","a")
file.write(" Judaism")
file.close()

# %%
with open ("C:/Users/RVUW262/Desktop/PYTHON-SCJ/LAB-4/LAB-4.2/tron.txt", "r") as file:
    print(file.read())
# Out:
# Tel AvivJudaism Judaism
