# %%
p={'mohiy':1234,'purvy':5698,'vishvy':789}
print(p)
# Out:
# {'mohiy': 1234, 'purvy': 5698, 'vishvy': 789}

# %%
p={
    'mohiy':1234,
    'purvy':5698,
    'vishvy':789
}
print(p)
# Out:
# {'mohiy': 1234, 'purvy': 5698, 'vishvy': 789}

# %%
p={'mohiy':1234,'purvy':5698,'vishvy':789}
print(p['purvy'])
# Out:
# 5698

# %%
p={'mohiy':1234,'purvy':5698,'vishvy':789}
print(p.get('mohiy'))
# Out:
# 1234

# %%
p={'mohiy':1234,'purvy':5698,'vishvy':789}
print(p)
print(p['vishvy'])
# Out:
# {'mohiy': 1234, 'purvy': 5698, 'vishvy': 789}
# 789

# %%
p={'mohiy':1234,'purvy':5698,'vishvy':789}
print(p['mohiy'])
print(p.get('Mohiy'))
print(p.get('mohiy'))
print(p['mohiy'])
# Out:
# 1234
# None
# 1234
# 1234

# %%
p=dict([ ('mohiy',1234),('purvy',5698),('vishvy',789)])
print(p)
# Out:
# {'mohiy': 1234, 'purvy': 5698, 'vishvy': 789}

# %%
p={
    'mohiy':1234,
    'purvy':5698,
    'vishvy':789
}
print(p)
p["mohiy"]={888,999,777}
print(p)
p["purvy"]={"purvy-home":7145585,"purvy-office":4569885}  # dictionary

print(p)

print(p["purvy"]["purvy-home"])
# Out:
# {'mohiy': 1234, 'purvy': 5698, 'vishvy': 789}
# {'mohiy': {888, 777, 999}, 'purvy': 5698, 'vishvy': 789}
# {'mohiy': {888, 777, 999}, 'purvy': {'purvy-home': 7145585, 'purvy-office': 4569885}, 'vishvy': 789}
# 7145585

# %%
p={
    'mohiy':1234,
    'purvy':5698,
    'vishvy':789
}
del p["vishvy"]
print(p)
# Out:
# {'mohiy': 1234, 'purvy': 5698}

# %%
dict1 = {'V': 10, 'P': 20}
dict2 = {'M': 30, 'S': 40}

m_dict = dict1 | dict2

print(m_dict)
# Out:
# {'V': 10, 'P': 20, 'M': 30, 'S': 40}
