# %%
a={1,2,3}
b=a.copy()
b
# Out:
# {1, 2, 3}

# %%
a
# Out:
# {1, 2, 3}

# %%
b
# Out:
# {1, 2, 3}

# %%
b.add(4)
b
# Out:
# {1, 2, 3, 4}

# %%
a-b
# Out:
# set()

# %%
b-a
# Out:
# {4}

# %%
b.discard(4)
b
# Out:
# {1, 2, 3}

# %%
a={1,2,3}
b={3,4,5,6}

a.intersection(b)
# Out:
# {3}

# %%
a.isdisjoint(b)
# Out:
# False

# %%
b.isdisjoint(a)
# Out:
# False

# %%
a={1,2}
b={3,4}

a.isdisjoint(b)
# Out:
# True

# %%
a={3,4}
b={3,4,5,6}

a.issubset(b)
# Out:
# True

# %%
b.issuperset(a)
# Out:
# True

# %%
a^b
# Out:
# {5, 6}

# %%
a={1,3,5}
b={2,4,6}

a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6}
