# %%
import array
arr = array.array('i', [10, 100, 30])
print(arr)
# Out:
# array('i', [10, 100, 30])

# %%
import array
a=array.array('i',[1,2,3,4,5,6])
for i in range (0,6):
    print(a[i])
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
import array
arr=array.array('i',[1,2,3,4,5,6])
arr.append(50)
print(arr)

arr12=array.array('i',sorted(arr))
print(arr12)

newarr=arr.tolist()
print(newarr)
# Out:
# array('i', [1, 2, 3, 4, 5, 6, 50])
# array('i', [1, 2, 3, 4, 5, 6, 50])
# [1, 2, 3, 4, 5, 6, 50]
