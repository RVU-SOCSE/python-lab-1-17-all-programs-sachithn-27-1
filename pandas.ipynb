# %%
import pandas as pd
data = pd.Series([10,20,30,40])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
data = {
    "Name":["Ram", "Vani"],
    "Age":[20,25]
}

df = pd.DataFrame(data)
print(df)
print("\n")
# Out:
#    Name  Age
# 0   Ram   20
# 1  Vani   25

# %%
df.isnull()
# Out:
#     Name    Age
# 0  False  False
# 1  False  False

# %%
data=pd.Series([10,20,30],index=["x","y","z"])
print(data)
# Out:
# x    10
# y    20
# z    30
# dtype: int64

# %%
df=pd.read_csv("C:\\Users\\RVUW262\\Desktop\\Trial.csv")
print(df)
# Out:
#       Name: Class:  Marks:
# 0    Purvaj    Bca    67.0
# 1     Mohit    BBA     NaN
# 2  Shourrya    NSS    69.0

# %%
df.isnull()
# Out:
#    Name:  Class:  Marks:
# 0  False   False   False
# 1  False   False    True
# 2  False   False   False

# %%
df.dropna()
# Out:
#       Name: Class:  Marks:
# 0    Purvaj    Bca    67.0
# 2  Shourrya    NSS    69.0

# %%
df.fillna(0)
# Out:
#       Name: Class:  Marks:
# 0    Purvaj    Bca    67.0
# 1     Mohit    BBA     0.0
# 2  Shourrya    NSS    69.0

# %%
print(df["Marks:"].mean())
print(df["Marks:"].sum())
print(df["Marks:"].min())
print(df["Marks:"].max())
print(df["Marks:"].count())
# Out:
# 68.0
# 136.0
# 67.0
# 69.0
# 2

# %%
df.shape
df.ndim
len(df)
df.index
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df.shape)
#       2 print(df.ndim)
#       3 len(df)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

data = {
    "ID": [1, 2, 3, 4],
    "Name": ["Charlie", "Alistor", "Angel", "Pentious"],
    "Marks": [88, 70, 32, 99]
}

df = pd.DataFrame(data)
df.to_csv("students.csv",index=False)

print("CSV file created successfully")
# Out:
# CSV file created successfully
