# %%
sentence = input("Enter a sentence: ")

words = sentence.split()
count = len(words)         

print(f"Number of words: {count}")
# Out:
# Enter a sentence:  I am the greatest person to ever exist. Without me the world wouldn't exist. If I die, the world dies.
# Number of words: 20
